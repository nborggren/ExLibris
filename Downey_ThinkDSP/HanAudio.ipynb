# %%
import soundfile as sf
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
sig, sr = sf.read('dat/eternal.wav')
print len(sig),sr,float(len(sig))/sr/60
# Out:
# 17424047 44100 6.58505177627

# %%
plt.plot(sig[:250000])

# %%
#no music from :50 to 1:50 from 50 to 110
beg=50*sr
end=110*sr
plt.plot(sig[beg:end])

# %%
plt.plot(sig[50*sr:80*sr])
